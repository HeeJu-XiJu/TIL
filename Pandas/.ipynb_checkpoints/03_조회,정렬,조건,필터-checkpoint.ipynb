# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 데이터셋
# ### 타이타닉: 탑승객의 사망자와 생존자 데이터 분석

# %%
df = sns.load_dataset("titanic")

# %% [markdown]
# ### 컬럼 (column) 설명
# - survivied: 생존여부 (1: 생존, 0: 사망)
# - pclass: 좌석 등급 (1등급, 2등급, 3등급)
# - sex: 성별
# - age: 나이
# - sibsp: 형제 + 배우자 수
# - parch: 부모 + 자녀 수
# - fare: 좌석 요금
# - embarked: 탑승 항구 (S, C, Q)
# - class: pclass와 동일
# - who: 성별과 동일
# - adult_male: 성인 남자 여부
# - deck: 데크 번호 (알파벳 + 숫자 혼용)
# - embark_town: 탑승 항구 이름
# - alive: 생존여부 (yes, no)
# - alone: 혼자 탑승 여부

# %% [markdown]
# ### head() 앞 부분 / tail() 뒷 부분 조회
# - default값으로 5개의 행 조회

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %% [markdown]
# ### info()
# - 컬럼별 정보(information)을 보여줌
# - 데이터의 갯수, 데이터 타입(dtype)을 확인할 때 사용

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# **object** type은 문자열

# %% [markdown]
# ### describe()
# - 각 칼럼에 대한 요약 통계 제공

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# categorical column (문자열 칼럼)은 ``include='object'``를 통해 요약 통계 확인 가능

# %%
df.describe(include='object')
# unique(고유값) : ex. woman, man, child 등)
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %% [markdown]
# ### value_counts()
# column별 값의 분포를 확인

# %%
df['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %% [markdown]
# ### 속성(Attributes)
# - ndim (차원)
# - shape (행, 열)
# - index (기본 설정된 RangeIndex)
# - columns (열)
# - values (모든 값, **numpy array 형식**)
# - T (Transpose 전치)

# %%
df.ndim # DataFrame은 2차원
# Out:
# 2

# %%
df.shape
# Out:
# (891, 15)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.values
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
df.T
# Out:
#                      0          1            2            3            4    \
# survived               0          1            1            1            0
# pclass                 3          1            3            1            3
# sex                 male     female       female       female         male
# age                 22.0       38.0         26.0         35.0         35.0
# sibsp                  1          1            0            1            0
# parch                  0          0            0            0            0
# fare                7.25    71.2833        7.925         53.1         8.05
# embarked               S          C            S            S            S
# class              Third      First        Third        First        Third
# who                  man      woman        woman        woman          man
# adult_male          True      False        False        False         True
# ...

# %% [markdown]
# ### 타입 변환 (astype)
# int32, float32, str(object), category 등으로 변경

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df['pclass'].astype('int32').head()
# Out:
# 0    3
# 1    1
# 2    3
# 3    1
# 4    3
# Name: pclass, dtype: int32

# %%
df['who'] = df['who'].astype('category')
df['who'].head()
# Out:
# 0      man
# 1    woman
# 2    woman
# 3    woman
# 4      man
# Name: who, dtype: category
# Categories (3, object): ['child', 'man', 'woman']

# %% [markdown]
# ``category`` 변환 후 ``.cat``으로 접근해 category타입이 제공하는 attribute 사용 가능

# %%
df['who'].cat.codes
# Out:
# 0      1
# 1      2
# 2      2
# 3      2
# 4      1
#       ..
# 886   -1
# 887   -1
# 888   -1
# 889   -1
# 890   -1
# Length: 891, dtype: int8

# %% [markdown]
# 카테고리 이름 변경

# %%
[f'Group({g})' for g in df['who'].cat.categories]
# Out:
# ['Group(child)', 'Group(man)', 'Group(woman)']

# %%
df['who'] = df['who'].cat.rename_categories([f'Group({g})' for g in df['who'].cat.categories])
df['who'].value_counts()
# Out:
# who
# Group(man)      537
# Group(woman)    271
# Group(child)     83
# Name: count, dtype: int64

# %% [markdown]
# ## 정렬(sort)
# ### sort_index : index 정렬
# - index기준으로 정렬(기본 오름차순)
# - 내림차순 정렬 : ``ascending = False``

# %%
df.sort_index().head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sort_index(ascending = False).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 890         0       3    male  32.0      0      0   7.75        Q   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 887         1       1  female  19.0      0      0  30.00        S   First
# 886         0       2    male  27.0      0      0  13.00        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 890    man        True  NaN   Queenstown    no   True
# 889    man        True    C    Cherbourg   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 887  woman       False    B  Southampton   yes   True
# 886    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### sort_values : 값에 대한 정렬

# %%
df.sort_values(by = 'age').head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False

# %%
# 내림차순 정렬
df.sort_values(by = 'age', ascending = False).head()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 630         1       1  male  80.0      0      0  30.0000        S  First  man
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
#
#      adult_male deck  embark_town alive  alone
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True
# 493        True  NaN    Cherbourg    no   True
# 96         True    A    Cherbourg    no   True
# 116        True  NaN   Queenstown    no   True

# %%
# 2개 이상의 칼럼정렬 가능 - fare 다음 deck 순 (문자열은 알파벳순으로 정렬)
df.sort_values(by = ['fare', 'deck'], ascending = [False, True]).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 679    man        True    B    Cherbourg   yes  False
# 737    man        True    B    Cherbourg   yes   True
# 258  woman       False  NaN    Cherbourg   yes   True
# 27     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False

# %% [markdown]
# ## Indexing, Slicing, 조건 필터링

# %% [markdown]
# ### loc - indexing / slicing
# - slicing : [시작(포함) : 끝(포함)]

# %%
# df.loc[행인덱스, 열인덱스]
df.loc[5, 'class']
# Out:
# 'Third'

# %%
# fancy indexing
df.loc[2:5, ['age', 'fare', 'who']]
# Out:
#     age     fare    who
# 2  26.0   7.9250  woman
# 3  35.0  53.1000  woman
# 4  35.0   8.0500    man
# 5   NaN   8.4583    man

# %%
# slicing
df.loc[:5, 'age':'deck']
# Out:
#     age  sibsp  parch     fare embarked  class    who  adult_male deck
# 0  22.0      1      0   7.2500        S  Third    man        True  NaN
# 1  38.0      1      0  71.2833        C  First  woman       False    C
# 2  26.0      0      0   7.9250        S  Third  woman       False  NaN
# 3  35.0      1      0  53.1000        S  First  woman       False    C
# 4  35.0      0      0   8.0500        S  Third    man        True  NaN
# 5   NaN      0      0   8.4583        Q  Third    man        True  NaN

# %% [markdown]
# ### loc - 조건 필터
# boolean index를 만들어 조건에 맞는 데이터만 추출

# %%
condition = df['who'] == 'man'

# df[condition]
df[condition].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %%
# df.loc[condition]
df.loc[condition].head()
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  22.0      1      0   7.2500        S  Third  man
# 4          0       3  male  35.0      0      0   8.0500        S  Third  man
# 5          0       3  male   NaN      0      0   8.4583        Q  Third  man
# 6          0       1  male  54.0      0      0  51.8625        S  First  man
# 12         0       3  male  20.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %% [markdown]
# 값 대입 시 문제가 발생하므로 loc 사용

# %%
df[condition]['age'] = 2
# Out:
# /var/folders/cr/4mctdycd44v5kxv5byzl08vr0000gn/T/ipykernel_3215/4257232175.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[condition]['age'] = 2

# %%
df.loc[condition, 'age'] = 2
df[condition].head()
# Out:
#     survived  pclass   sex  age  sibsp  parch     fare embarked  class  who  \
# 0          0       3  male  2.0      1      0   7.2500        S  Third  man
# 4          0       3  male  2.0      0      0   8.0500        S  Third  man
# 5          0       3  male  2.0      0      0   8.4583        Q  Third  man
# 6          0       1  male  2.0      0      0  51.8625        S  First  man
# 12         0       3  male  2.0      0      0   8.0500        S  Third  man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 5         True  NaN   Queenstown    no   True
# 6         True    E  Southampton    no   True
# 12        True  NaN  Southampton    no   True

# %%
df = sns.load_dataset("titanic")
con = df['age'] < 10
df.loc[con].head()
# Out:
#     survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 7          0       3    male  2.0      3      1  21.0750        S   Third
# 10         1       3  female  4.0      1      1  16.7000        S   Third
# 16         0       3    male  2.0      4      1  29.1250        Q   Third
# 24         0       3  female  8.0      3      1  21.0750        S   Third
# 43         1       2  female  3.0      1      2  41.5792        C  Second
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 10  child       False    G  Southampton   yes  False
# 16  child       False  NaN   Queenstown    no  False
# 24  child       False  NaN  Southampton    no  False
# 43  child       False  NaN    Cherbourg   yes  False

# %% [markdown]
# ### loc - 다중조건
# 다중조건은 condition을 정의하고 ``&(and)``와 ``|(or)`` 연산자로 복합조건을 생성

# %%
condition1 = df['fare'] > 30
condition2 = df['who'] == 'woman'
df.loc[condition1 & condition2]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 25          1       3  female  38.0      1      5   31.3875        S  Third
# 31          1       1  female   NaN      1      0  146.5208        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 853         1       1  female  16.0      0      1   39.4000        S  First
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.loc[condition1 | condition2]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### iloc
# - `loc`와 유사하지만, index만 허용
# - loc와 마찬가지로 indexing/slicing 모두 가능

# %% [markdown]
# #### indexing

# %%
df.iloc[1, 3] # 1행 3열
# Out:
# 38.0

# %% [markdown]
# #### fancy indexing

# %%
df.iloc[[0, 3, 4], [0, 1, 5, 6]]
# Out:
#    survived  pclass  parch   fare
# 0         0       3      0   7.25
# 3         1       1      0  53.10
# 4         0       3      0   8.05

# %% [markdown]
# #### slicing

# %%
df.iloc[:3, :5]
# Out:
#    survived  pclass     sex   age  sibsp
# 0         0       3    male  22.0      1
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0

# %% [markdown]
# #### where
# [document](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.where.html) \
# `DataFrame.where(cond, other=nan, inplace=False, axis=None, level=None, errors='raise', try_cast=False)`
# - cond : True/False로 판단될 수 있는 식
# - other : condition을 만족하지 못하는 요소에 할당할 값

# %%
df['fare'].where(df['fare'] < 20, 0).tail(10)
# Out:
# 881     7.8958
# 882    10.5167
# 883    10.5000
# 884     7.0500
# 885     0.0000
# 886    13.0000
# 887     0.0000
# 888     0.0000
# 889     0.0000
# 890     7.7500
# Name: fare, dtype: float64

# %% [markdown]
# 전체 DataFrame에 적용 시 조건이 해당하는 값 외에는 모두 NaN

# %%
df.where(df['fare'] < 10)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 0         0.0     3.0    male  22.0    1.0    0.0  7.250        S  Third
# 1         NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 2         1.0     3.0  female  26.0    0.0    0.0  7.925        S  Third
# 3         NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 4         0.0     3.0    male  35.0    0.0    0.0  8.050        S  Third
# ..        ...     ...     ...   ...    ...    ...    ...      ...    ...
# 886       NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 887       NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 888       NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 889       NaN     NaN     NaN   NaN    NaN    NaN    NaN      NaN    NaN
# 890       0.0     3.0    male  32.0    0.0    0.0  7.750        Q  Third
#
#        who adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### isin
# 특정 값의 포함 여부 확인 가능

# %%
sample = pd.DataFrame({'name': ['kim', 'lee', 'park', 'choi'], 
                        'age': [24, 27, 34, 19]
                      })
sample
# Out:
#    name  age
# 0   kim   24
# 1   lee   27
# 2  park   34
# 3  choi   19

# %%
sample['name'].isin(['kim', 'lee'])
# c1 = sample['name'] == 'kim'
# c2 = sample['name'] == 'lee'
# sample.loc[c1 | c2]
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: name, dtype: bool

# %%
sample.isin(['kim', 'lee'])
# Out:
#     name    age
# 0   True  False
# 1   True  False
# 2  False  False
# 3  False  False

# %%
condition = sample['name'].isin(['kim', 'lee'])
sample.loc[condition]
# Out:
#   name  age
# 0  kim   24
# 1  lee   27
